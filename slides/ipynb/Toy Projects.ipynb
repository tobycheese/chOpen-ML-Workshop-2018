# %%
from traitlets.config.manager import BaseJSONConfigManager
path = "~/.jupyter/nbconfig"
cm = BaseJSONConfigManager(config_dir=path)
cm.update('livereveal', {
              'theme': 'solarized',
              'transition': 'slide', # none/fade/slide/convex/concave/zoom
              'start_slideshow_at': 'selected',
              'scroll': False,
              'history': False ,
              'progress': True,
})
# Out:
# {'theme': 'solarized',
#  'transition': 'slide',
#  'start_slideshow_at': 'selected',
#  'scroll': False,
#  'history': False,
#  'progress': True}

# %% [markdown]
# # Toy Projects

# %% [markdown]
# ### Toy Projects
# * **Cloud and Faces**: Flickr API, Cleaning, Face Detection, Google Cloud Vision (Übung, lokal)
#
# * **Trumps Tweets**: Monkeylearn API, Pandas, Supervised Learning (Übung, lokal)
#
# * **Bricks and More**: Keras, Transfer Learning, Convolutional Neural Network (Tutorial, auf *Google Colab*, siehe bricks_and_more/README.md auf Github)

# %% [markdown]
# ### Advanced
# * [Scikit Learn Tutorial](http://scikit-learn.org/stable/tutorial/basic/tutorial.html)
# * [John Wittenauer's Machine Learning Basics](http://www.johnwittenauer.net/machine-learning-exercises-in-python-part-1/)
# * [Magnus Erik Hvass Pedersen's Tensorflow Tutorials](https://github.com/Hvass-Labs/TensorFlow-Tutorials)
